# %%
class AC:
    def __init__ (self,name,color):
        self.name=name
        self.color=color
        self.lowesttemp=16
        self.maxtemp=30
        self.switch= False
        self.temp=0
        
    def Utility(self):
        print("It changes room temprature by condensing the room air")
        
    def Turnon(self):
        self.switch=True
        print("Turned on")
        self.temp=23
    
    def Turnoff(self):
        self.switch=False
        print('Switched Off')
        self.temp=0
        
    def mode(self):
        mode1= input("choose hot/cold/neu : ")
        if mode1=="hot":
            print ("temprature set to 16 as it is too hot")
            self.temp=16
        elif mode1=="cold":
            print("temprature set to 28 as it is too cold")
            self.temp=28
        elif mode1=="neu":
            print("temprature set to 23 as neutral mode")
            self.temp=23
        else:
            print("not available")

    def inctemp(self):
        if self.switch == True:
            if self.temp+1>self.maxtemp:
                print('Not Possible')
            else:
                self.temp+=1
                
        
                
                
    def gettemp(self):
        return self.temp
            
        
AC1=AC('LG','white')
AC1.name
AC1.color
AC1.gettemp()
AC1.Turnon()
AC1.gettemp()
AC1.inctemp()
